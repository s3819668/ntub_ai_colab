# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance-2.csv")
df.head()
# Out:
#    Unnamed: 0  gender ethnicity              parEdu         lunch   testPrep  \
# 0           0  female   group B   bachelor's degree      standard       none
# 1           1  female   group C        some college      standard  completed
# 2           2  female   group B     master's degree      standard       none
# 3           3    male   group A  associate's degree  free/reduced       none
# 4           4    male   group C        some college      standard       none
#
#    math  reading  writing  mathPass
# 0    72       72       74         1
# 1    69       90       88         1
# 2    90       95       93         1
# 3    47       57       44         0
# 4    76       78       75         1

# %%
df.to_csv("StudentsPerformance-3.csv", index=False)
