# %%
import pandas as pd
data=pd.read_csv('nba.csv')
data.head()
# Out:
#           姓  背號   位置    身高     體重          生日      助攻      火鍋     抄截      失誤  \
# 0   Achiuwa   5    F  2.03  102.1  1999-09-19   111.0    69.0   57.0   127.0
# 1     Adams   4    C  2.11  120.2  1993-07-20   982.0   629.0  588.0   950.0
# 2   Adebayo  13  C-F  2.06  115.7  1997-07-18  1189.0   309.0  340.0   708.0
# 3    Aldama   7  F-C  2.11   97.5  2001-01-10    21.0    10.0    6.0    16.0
# 4  Aldridge  21  C-F  2.11  113.4  1985-07-19  2076.0  1187.0  758.0  1643.0
#
#      總計籃板    命中次數     出手次數  罰球命中次數    罰球次數       得分    上場場次   先發場次    總上場分鐘
# 0   681.0   389.0    831.0   134.0   241.0    968.0   134.0   32.0   2461.0
# 1  5303.0  2556.0   4356.0  1044.0  1907.0   6157.0   664.0  599.0  17811.0
# 2  2850.0  1756.0   3145.0  1098.0  1481.0   4617.0   343.0  239.0   9665.0
# 3    87.0    53.0    132.0    20.0    32.0    132.0    32.0    0.0    359.0
# 4  8736.0  8311.0  16872.0  3709.0  4563.0  20558.0  1076.0  997.0  36242.0

# %% [markdown]
# 散佈圖

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,7)})
sns.scatterplot(x=data.身高,y=data.體重)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 39636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# 過濾

# %%
data[(data.體重>125)&(data.身高<2.0)]
# Out:
#               姓  背號 位置    身高     體重          生日     助攻    火鍋    抄截     失誤  \
# 486  Williamson   1  F  1.98  128.8  2000-07-06  276.0  48.0  73.0  226.0
#
#       總計籃板   命中次數    出手次數  罰球命中次數   罰球次數      得分  上場場次  先發場次   總上場分鐘
# 486  591.0  844.0  1397.0   483.0  707.0  2187.0  85.0  85.0  2694.0

# %%
data[(data.體重<90)&(data.身高>2.1)]
# Out:
#               姓  背號 位置    身高    體重          生日     助攻    火鍋    抄截     失誤  \
# 362  Pokusevski  17  F  2.13  86.2  2001-12-26  228.0  80.0  59.0  193.0
#
#       總計籃板   命中次數   出手次數  罰球命中次數  罰球次數     得分   上場場次  先發場次   總上場分鐘
# 362  530.0  325.0  864.0    66.0  92.0  831.0  106.0  40.0  2322.0

# %%
data[data.姓=='Curry']
# Out:
#          姓  背號 位置    身高    體重          生日      助攻     火鍋      抄截      失誤  \
# 109  Curry  30  G  1.88  83.9  1990-08-23   832.0   53.0   274.0   425.0
# 110  Curry  30  G  1.88  83.9  1988-03-14  5388.0  187.0  1367.0  2598.0
#
#        總計籃板    命中次數     出手次數  罰球命中次數    罰球次數       得分   上場場次   先發場次    總上場分鐘
# 109   843.0  1555.0   3263.0   405.0   474.0   4245.0  377.0  199.0   9489.0
# 110  3838.0  6875.0  14520.0  3197.0  3520.0  20064.0  826.0  820.0  28361.0

# %%
data[data.姓.str.contains('aa')]
# Out:
#          姓  背號 位置    身高     體重          生日     助攻     火鍋     抄截     失誤   總計籃板  \
# 218  Isaac   1  F  2.08  104.3  1997-10-03  146.0  206.0  145.0  151.0  741.0
#
#       命中次數    出手次數  罰球命中次數   罰球次數      得分   上場場次   先發場次   總上場分鐘
# 218  473.0  1088.0   189.0  237.0  1269.0  136.0  106.0  3511.0

# %% [markdown]
# 切割

# %%
data.iloc[:5 ,:3]
# Out:
#           姓  背號   位置
# 0   Achiuwa   5    F
# 1     Adams   4    C
# 2   Adebayo  13  C-F
# 3    Aldama   7  F-C
# 4  Aldridge  21  C-F

# %%
data.loc[:10,['身高','生日']]
# Out:
#       身高          生日
# 0   2.03  1999-09-19
# 1   2.11  1993-07-20
# 2   2.06  1997-07-18
# 3   2.11  2001-01-10
# 4   2.11  1985-07-19
# 5   1.96  1998-09-02
# 6   1.93  1995-10-08
# 7   2.08  1998-04-21
# 8   1.83  1998-04-12
# 9   2.06  1993-09-20
# 10  2.11  1994-12-06
