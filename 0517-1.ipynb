# %%
import pandas as pd

df=pd.read_csv('nba2.csv')
df.head()

# %% [markdown]
# 取得單一欄位資料

# %%
print(df.height)
print(type(df.height))
# Out:
# 0      2.03
# 1      2.11
# 2      2.06
# 3      2.11
# 4      2.11
#        ...
# 495    1.80
# 496    2.03
# 497    1.85
# 498    2.11
# 499    2.13
# Name: height, Length: 500, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
print(df['height'])
print(type(df['height']))

# %%
print(df[['height']])
print(type(df[['height']]))#[[]] DataFrame

# %%
df[['height','weight']]

# %% [markdown]
# info()/describe()/shape

# %%
df.info()

# %%
df.describe()

# %%
df.shape
# Out:
# (500, 19)
