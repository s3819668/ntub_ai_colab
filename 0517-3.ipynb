# %%
import pandas as pd
df =pd.read_csv('titanic.csv')
df.head()
# Out:
#    Unnamed: 0  no pclass                                               name  \
# 0           0   0      C                            Braund, Mr. Owen Harris
# 1           1   1      A  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           2   2      C                             Heikkinen, Miss. Laina
# 3           3   3      A       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           4   4      C                           Allen, Mr. William Henry
#
#    gender   age  sibsp  parch            ticket     fare cabin embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   survived
# 0        N
# 1        Y
# 2        Y
# 3        Y
# 4        N

# %%
df.columns
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   no        1309 non-null   int64
#  1   pclass    1309 non-null   object
#  2   name      1309 non-null   object
#  3   gender    1309 non-null   object
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   object
#  8   fare      1308 non-null   float64
#  9   cabin     295 non-null    object
#  10  embarked  1307 non-null   object
#  11  survived  1309 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 122.8+ KB

# %%
df[df.name.str.contains('Jack')]
# Out:
#       no pclass                       name gender  age  sibsp  parch  ticket  \
# 766  766      A  Brewe, Dr. Arthur Jackson   male  NaN      0      0  112379
#
#      fare cabin embarked survived
# 766  39.6   NaN        C        N

# %%
df[df.pclass=='A']
# Out:
#         no pclass                                               name  gender  \
# 1        1      A  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3        3      A       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 6        6      A                            McCarthy, Mr. Timothy J    male
# 11      11      A                           Bonnell, Miss. Elizabeth  female
# 23      23      A                       Sloper, Mr. William Thompson    male
# ...    ...    ...                                                ...     ...
# 1294  1294      A                             Carrau, Mr. Jose Pedro    male
# 1295  1295      A                       Frauenthal, Mr. Isaac Gerald    male
# 1298  1298      A                         Widener, Mr. George Dunton    male
# 1302  1302      A    Minahan, Mrs. William Edward (Lillian E Thorpe)  female
# 1305  1305      A                       Oliva y Ocana, Dona. Fermina  female
#
#        age  sibsp  parch    ticket      fare cabin embarked survived
# 1     38.0      1      0  PC 17599   71.2833   C85        C        Y
# 3     35.0      1      0    113803   53.1000  C123        S        Y
# 6     54.0      0      0     17463   51.8625   E46        S        N
# 11    58.0      0      0    113783   26.5500  C103        S        Y
# 23    28.0      0      0    113788   35.5000    A6        S        Y
# ...    ...    ...    ...       ...       ...   ...      ...      ...
# 1294  17.0      0      0    113059   47.1000   NaN        S        N
# 1295  43.0      1      0     17765   27.7208   D40        C        N
# 1298  50.0      1      1    113503  211.5000   C80        C        N
# 1302  37.0      1      0     19928   90.0000   C78        Q        Y
# 1305  39.0      0      0  PC 17758  108.9000  C105        C        Y
#
# [323 rows x 12 columns]

# %%
df.pclass.value_counts(normalize=True)
# Out:
# C    0.541635
# A    0.246753
# B    0.211612
# Name: pclass, dtype: float64

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(7,5)})
sns.countplot(data=df,x='gender',hue='survived')

# %%
sns.countplot(data=df,x='pclass',hue='survived')

# %%
sns.countplot(data=df,x='pclass',hue='embarked')
